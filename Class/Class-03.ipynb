# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Piloto 01\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Piloto 01\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Piloto 01\anaconda3\envs\CursoDeMAchingLearning\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Piloto 01\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'dataset.csv')
data
# Out:
#       target      var1      var2      var3      var4      var5      var6  \
# 0          1 -0.249787  2.121908  0.407648  1.964749  0.199461  3.651492
# 1          0  1.060270  2.229403  0.440553  2.616826  0.817489  2.922979
# 2          1  2.472869  2.286277  0.465138  2.523258  0.375064  2.490611
# 3          0 -0.331834  2.161892 -0.068147  2.005119  0.013024  3.366682
# 4          1  0.538387  2.167229  0.584691  1.511262 -0.163058  2.997613
# ...      ...       ...       ...       ...       ...       ...       ...
# 9995       0  2.739141  2.485702  0.350469  2.543638  0.291247  2.367032
# 9996       0  1.056760  2.196624  0.752964  5.465917  1.980148  2.845145
# 9997       0 -0.142683  2.117035  0.316059  2.292217  1.746763  3.516194
# 9998       0  1.621580  2.214573  0.909534  2.524898  0.369124  2.883814
# 9999       0  2.078494  2.219952  1.153743  4.773494  1.616940  2.789362
#
#           var7      var8      var9     var10     var11       var12      var13  \
# 0     4.407901  1.570663  3.965790  3.945533  0.197857  289.043765  50.638945
# 1     2.431303  1.631324  3.785059  4.093037  0.165174  297.555309  41.886965
# 2     0.581821  0.925485  3.798064  4.118556  0.116712  292.203781  39.564444
# 3     3.873151  1.389452  3.703492  4.420865 -0.019777  288.899425  38.863698
# 4     2.712657  1.063145  3.667643  4.805387 -0.004894  298.810890  46.138542
# ...        ...       ...       ...       ...       ...         ...        ...
# 9995 -0.081074  0.822117  3.852542  4.621403  0.013964  298.470093  42.189715
# 9996  2.018792  3.731225  3.708889  4.555245 -0.018636  293.810272  44.838131
# 9997  4.413810  1.232628  3.659542  3.212645  0.453572  294.879599  40.251493
# 9998  1.505649  1.175122  3.705286  4.340695  0.088577  286.253976  46.071693
# 9999  1.409463  3.332703  3.862870  3.723933  0.319563  291.127568  37.084528
#
#           var14  var15     var16
# 0     11.813714   42.0  0.412265
# 1     13.684621   42.0  0.441173
# 2     14.389293   42.0  0.465607
# 3     13.990813   42.0 -0.068971
# 4     13.327931   42.0  0.589430
# ...         ...    ...       ...
# 9995  13.171125   42.0  0.350614
# 9996  14.295483   42.0  0.745624
# 9997  13.790604   42.0  0.315472
# 9998  15.650315   42.0  0.908657
# 9999  11.349951   42.0  1.161150
#
# [10000 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  10000 non-null  int64
#  1   var1    10000 non-null  float64
#  2   var2    10000 non-null  float64
#  3   var3    10000 non-null  float64
#  4   var4    10000 non-null  float64
#  5   var5    10000 non-null  float64
#  6   var6    10000 non-null  float64
#  7   var7    10000 non-null  float64
#  8   var8    10000 non-null  float64
#  9   var9    10000 non-null  float64
#  10  var10   10000 non-null  float64
#  11  var11   10000 non-null  float64
#  12  var12   10000 non-null  float64
#  13  var13   10000 non-null  float64
#  14  var14   10000 non-null  float64
#  15  var15   10000 non-null  float64
#  16  var16   10000 non-null  float64
# dtypes: float64(16), int64(1)
# memory usage: 1.3 MB

# %%
data.describe()
# Out:
#             target          var1          var2          var3          var4  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.31460      1.041957   1678.734830   1677.217633      2.975683
# std        0.46438      0.884508  10391.950014  10392.194814      1.157038
# min        0.00000     -0.603788  -9782.758399  -9782.758399      0.777764
# 25%        0.00000      0.319062      2.114084      0.398036      2.147795
# 50%        0.00000      0.917863      2.158831      0.608327      2.618077
# 75%        1.00000      1.660586      2.246108      0.875455      3.537568
# max        1.00000      3.341215  99959.752415  99959.752415      6.227424
#
#                var5          var6          var7          var8          var9  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.758081      2.949842      2.175353      1.612470      3.759351
# std        0.786009      0.335780      1.313214      0.796681      0.108960
# min       -0.853872      1.888814     -1.712754     -0.045757      3.229211
# 25%        0.128182      2.717184      1.269951      1.026949      3.690653
# 50%        0.427599      2.969044      2.272818      1.283400      3.761519
# 75%        1.469202      3.191298      3.130095      2.055805      3.828883
# max        5.300846      4.178478      7.275910      4.104236      4.306688
#
#               var10         var11         var12         var13         var14  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       4.278009      0.080652    292.306975     43.613269     14.255338
# std        0.482554      0.284146      8.417682      3.740078      1.454151
# min        0.047000     -0.991588    260.088648     34.658597      6.908544
# 25%        4.146649     -0.076011    286.638568     40.536869     13.350519
# 50%        4.410902      0.002178    292.379731     43.369436     14.457307
# 75%        4.550120      0.164565    298.053190     46.538461     15.321811
# max        5.385334      2.444563    323.693083     54.517740     19.990850
#
#          var15         var16
# count  10000.0  10000.000000
# mean      42.0      0.625058
# std        0.0      0.353886
# min       42.0     -0.837372
# 25%       42.0      0.391257
# 50%       42.0      0.594714
# 75%       42.0      0.838428
# max       42.0      2.040987

# %%
print(type(data))
# Out:
# <class 'pandas.DataFrame'>

# %%
data.dtypes
# Out:
# target      int64
# var1      float64
# var2      float64
# var3      float64
# var4      float64
# var5      float64
# var6      float64
# var7      float64
# var8      float64
# var9      float64
# var10     float64
# var11     float64
# var12     float64
# var13     float64
# var14     float64
# var15     float64
# var16     float64
# dtype: object

# %%
data.shape
# Out:
# (10000, 17)

# %%
data.isnull().sum()
# Out:
# target    0
# var1      0
# var2      0
# var3      0
# var4      0
# var5      0
# var6      0
# var7      0
# var8      0
# var9      0
# var10     0
# var11     0
# var12     0
# var13     0
# var14     0
# var15     0
# var16     0
# dtype: int64

# %%
plt.figure(figsize=(10, 2))
plt.subplot(1, 2, 1)
sns.boxplot(x=data['var1'])
plt.subplot(1, 2, 2)
sns.boxplot(x=data['var2'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 2))
plt.subplot(1, 2, 1)
sns.violinplot(x=data['var1'], color="blue")
plt.subplot(1, 2, 2)
sns.violinplot(x=data['var2'], color="blue")
plt.tight_layout()
plt.show()

# %%
data_no_outliers = data.copy()
for col in data_no_outliers.select_dtypes(include=[np.number]).columns:
    Q1 = data_no_outliers[col].quantile(0.25) # Primer quartile (25%)
    Q3 = data_no_outliers[col].quantile(0.75) # Tercer quartile (75%)
    IQR = Q3 - Q1 # Rango interquartile
    # limites IQR
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
# contador
    outliers_count = (
    (data_no_outliers[col] < lower_bound)
    | (data_no_outliers[col] > upper_bound)
    ).sum()
    # apping
    data_no_outliers[col] = np.clip(data_no_outliers[col], lower_bound, upper_bound)
    print(f"'{col}': {outliers_count} outliers capped
    |   Bounds: [{lower_bound:.2f}, {upper_bound:.2f}]")
    print("\nOutlier capping completed.")
# Out:
#   Cell In[21], line 16
#     print(f"'{col}': {outliers_count} outliers capped
#           ^
# SyntaxError: unterminated f-string literal (detected at line 16)
